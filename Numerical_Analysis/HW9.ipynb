# %% [markdown]
# # Numerical Methods HW 9

# %%
@interact
def Fonts(text = input_box(default = "Evergreen", type=str)):
    
    # Make Text lowercase
    text = text.lower()
    
    # blank
    pl = list_plot([(2.5,0)])
    
    ############
    # E points #
    ############
    e_points = [(3.5,2.3), (3,2.3), (3,1.8), (3.2,1.8), (3,1.8), (3,1.3),(3.5,1.3)]

    e_points1 = [(t, e_points[t][0]) for t in range(len(e_points))]
    e_points2 = [(t, e_points[t][1]) for t in range(len(e_points))]

    if 'e' in text:
        e1 = spline(e_points1)
        e2 = spline(e_points2)
        pl += list_plot(e_points, color='green', size=50)
        pl +=parametric_plot((e1,e2), (x, 0, len(e_points)-1))
    
    ############
    # V points #
    ############
    v_points = [(3.8, 2.3), (4, 1.2), (4.5,2.3)]
    v_points1 = [(t, v_points[t][0]) for t in range(len(v_points))]
    v_points2 = [(t, v_points[t][1]) for t in range(len(v_points))]
    if 'v' in text:
        v1 = spline(v_points1)
        v2 = spline(v_points2)
        pl += list_plot(v_points, color='green', size=50)
        pl +=parametric_plot((v1,v2), (x, 0, len(v_points)-1))
        
    ############
    # E points #
    ############
    e_points = [(5.2,2.3), (4.7,2.3), (4.7,1.8), (4.9,1.8), (4.7,1.8), (4.7,1.3), (5.2,1.3)]

    e_points1 = [(t, e_points[t][0]) for t in range(len(e_points))]
    e_points2 = [(t, e_points[t][1]) for t in range(len(e_points))]

    if 'e' in text:
        e1 = spline(e_points1)
        e2 = spline(e_points2)
        pl += list_plot(e_points, color='green', size=50)
        pl +=parametric_plot((e1,e2), (x, 0, len(e_points)-1))
    
    ############
    # R points #
    ############
    r_points = [(5.3, 1.3), (5.3, 1.8), (5.3, 2.3), (5.6, 2.3), (5.8, 2), (5.5, 1.8), (5.7,1.3), (5.5, 1.8), (5.3,1.8)]
    r_points1 = [(t, r_points[t][0]) for t in range(len(r_points))]
    r_points2 = [(t, r_points[t][1]) for t in range(len(r_points))]
    if 'r' in text:
        r1 = spline(r_points1)
        r2 = spline(r_points2)
        pl += list_plot(r_points, color='green', size=50)
        pl +=parametric_plot((r1,r2), (x, 0, len(r_points)-1))
        
    ############
    # G points #
    ############
    g_points = [(6.5, 2.2), (6.2, 2.3), (5.9, 1.8), (6.2, 1.3), (6.5, 1.5), (6.5, 1.6), (6.3, 1.6)]
    g_points1 = [(t, g_points[t][0]) for t in range(len(g_points))]
    g_points2 = [(t, g_points[t][1]) for t in range(len(g_points))]
    if 'g' in text:
        g1 = spline(g_points1)
        g2 = spline(g_points2)
        pl += list_plot(g_points, color='green', size=50)
        pl +=parametric_plot((g1,g2), (x, 0, len(g_points)-1))
        
    ############
    # R points #
    ############
    r_points = [(6.6, 1.3), (6.6, 1.8), (6.6, 2.3), (6.9, 2.3), (7.1, 2), (6.8, 1.8), (7, 1.3), (6.8, 1.8), (6.6,1.8)]
    r_points1 = [(t, r_points[t][0]) for t in range(len(r_points))]
    r_points2 = [(t, r_points[t][1]) for t in range(len(r_points))]
    if 'r' in text:
        r1 = spline(r_points1)
        r2 = spline(r_points2)
        pl += list_plot(r_points, color='green', size=50)
        pl +=parametric_plot((r1,r2), (x, 0, len(r_points)-1))
        
    ############
    # E points #
    ############
    e_points = [(7.8, 2.3), (7.3, 2.3), (7.3, 1.8), (7.5, 1.8), (7.3, 1.8), (7.3, 1.3), (7.8,1.3)]
    e_points1 = [(t, e_points[t][0]) for t in range(len(e_points))]
    e_points2 = [(t, e_points[t][1]) for t in range(len(e_points))]

    if 'e' in text:
        e1 = spline(e_points1)
        e2 = spline(e_points2)
        pl += list_plot(e_points, color='green', size=50)
        pl +=parametric_plot((e1,e2), (x, 0, len(e_points)-1))
        
    ############
    # E points #
    ############
    e_points = [(8.6, 2.3), (8.1, 2.3), (8.1, 1.8), (8.3, 1.8), (8.1, 1.8), (8.1, 1.3), (8.6,1.3)]

    e_points1 = [(t, e_points[t][0]) for t in range(len(e_points))]
    e_points2 = [(t, e_points[t][1]) for t in range(len(e_points))]

    if 'e' in text:
        e1 = spline(e_points1)
        e2 = spline(e_points2)
        pl += list_plot(e_points, color='green', size=50)
        pl +=parametric_plot((e1,e2), (x, 0, len(e_points)-1))
        
    ############
    # N points #
    ############
    n_points = [(8.8,1.3), (8.8,1.8), (8.8, 2.3), (9.2, 1.3), (9.2, 2.3)]
    n_points1 = [(t, n_points[t][0]) for t in range(len(n_points))]
    n_points2 = [(t, n_points[t][1]) for t in range(len(n_points))]
    if 'n' in text:
        n1 = spline(n_points1)
        n2 = spline(n_points2)
        pl += list_plot(n_points, color='green', size=50)
        pl +=parametric_plot((n1,n2), (x, 0, len(n_points)-1))
        
    
    pl.show()
# Out:
# Interactive function <function Fonts at 0x6ffed28c8b00> with 1 widget
#   text: TransformText(value='Evergreen',…
